# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import os
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("neurocipher/house-price-for-linear-regression")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Aksha\.cache\kagglehub\datasets\neurocipher\house-price-for-linear-regression\versions\1

# %%
file_path = os.path.join(path,"Housing.csv")
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
features = ['area']
X = df[features]
y = df.price

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
print(reg.score(X_test, y_test))
# Out:
# 0.3762429143188355

# %%
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')

plt.show()
